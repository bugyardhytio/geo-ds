# %%
import rioxarray
import xarray as Xarray
import Dask
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import rioxarray
#       2 import xarray as Xarray
# ----> 3 import Dask
#
# ModuleNotFoundError: No module named 'Dask'

# %%
data = Xarray.DataArray("2023-02-07-00_00_2023-02-07-23_59_Sentinel-2_L1C_True_color.tiff")

# %%
data.dims
# Out:
# ()

# %%
data.dtype
# Out:
# dtype('<U64')
